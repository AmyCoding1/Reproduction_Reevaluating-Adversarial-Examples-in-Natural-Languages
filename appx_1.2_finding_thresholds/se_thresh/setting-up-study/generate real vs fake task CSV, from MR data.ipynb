# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Project_AI
# !ls
# Out:
# /content/drive/MyDrive/Project_AI
#  200_sampled_per_run.csv  'Project_Reproduction_AI_Amarilda Koka'
#  bert_output.csv	   Reevaluating-NLP-Adversarial-Examples
#  case_study_examples.csv   Reevaluating-NLP-Adversarial-Examples-master
#  outputs		   training_output.csv

# %%
import pandas as pd

# %%
bert_df = pd.read_csv('/content/drive/MyDrive/Project_AI/Reevaluating-NLP-Adversarial-Examples/appx_1.2_finding_thresholds/se_thresh/setting-up-study/bert-thresh-examples.csv')

bert_df.columns
# Out:
# Index(['index', 'label_1', 'label_2', 'passage_1', 'passage_2', 'score_1',
#        'score_2', 'SE_Thresh', 'dataset', 'SE_Model'],
#       dtype='object')

# %%
mr_df = bert_df[(bert_df['SE_Thresh'] == .98) & (bert_df['dataset'] == 'mr')]

print(mr_df.shape)

mr_df.head()
# Out:
# (88, 10)
#      index  label_1  label_2  \
# 840      0      1.0      0.0
# 841      1      0.0      1.0
# 842      2      0.0      1.0
# 843      3      0.0      1.0
# 844      4      0.0      1.0
#
#                                              passage_1  \
# 840  paid in full is remarkably engaging despite be...
# 841  this movie , a certain scene in particular , b...
# 842  mr . wedge and mr . saldanha handle the mix of...
# 843  for a film that celebrates radical , nonconfor...
# 844  …passable enough for a shoot-out in the o . k ...
#
#                                              passage_2   score_1   score_2  \
# 840  paid in full is surprisingly engage albeit bei...  0.979929  0.612623
# 841  this movie , a certain scene in particular , b...  0.615160  0.597479
# 842  mr . wedge and mr . saldanha handle the blendi...  0.767221  0.604759
# 843  for a films that celebrate radical , nonconfor...  0.760463  0.541838
# 844  …passable enough for a shoot-out in the o . k ...  0.736965  0.560818
#
#      SE_Thresh dataset SE_Model
# 840       0.98      mr     BERT
# 841       0.98      mr     BERT
# 842       0.98      mr     BERT
# 843       0.98      mr     BERT
# 844       0.98      mr     BERT

# %%
real_df = mr_df['passage_1'].to_frame()
real_df.rename(columns={ 'passage_1': 'text'}, inplace=True)
real_df['label'] = 'real'

fake_df = mr_df['passage_2'].to_frame()
fake_df.rename(columns={ 'passage_2': 'text'}, inplace=True)
fake_df['label'] = 'fake'

full_df = pd.concat((real_df, fake_df))
print(full_df.shape)

full_df = full_df.sample(frac=1).reset_index(drop=True)
full_df.head()
# Out:
# (176, 2)
#                                                 text label
# 0  schnitzler's film has a great hook , some clev...  fake
# 1  an awful film that will only satisfy the most ...  fake
# 2  the most memorable moment was when green threw...  fake
# 3  ice age is the first computer-generated featur...  real
# 4  the movie is amateurish , but it's a minor tre...  real

# %%
full_df['text'].value_counts().sum()
# Out:
# 176

# %%
full_df['label'].value_counts()
# Out:
# fake    88
# real    88
# Name: label, dtype: int64

# %%
full_df.to_csv('tf-cf-0.9-bert-0.98.csv')
